# %% [markdown]
# <a href="https://colab.research.google.com/github/thammich/ENGR-1110-Project/blob/main/Homelessness_in_The_U_S_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Testing

# %% [markdown]
# This is a good example (https://colab.research.google.com/drive/1v6NeUvjPGLBtovSJ6z7vKX6N7d-Rh_rq?usp=sharing#scrollTo=OlUQb3grVF1-.) - could base it off this
#
# **Trello Board**
# - https://trello.com/invite/b/66fabe52d12a9910b5c4eb38/ATTId07c4bd36be235a48aba9905e30f21d3D230268D/engr-1110-group-project
#
# **Possible Datasets**
# - https://catalog.data.gov/dataset/covid-19-homeless-impact (covid-19 specific)
# - https://www.kaggle.com/datasets/barri12/homelessness (recent state specific)
# - https://www.kaggle.com/datasets/programmerrdai/homelessness (U.S. over years) - best one
# - https://www.kaggle.com/datasets/bigquery/sdoh-hud-pit-homelessness (uses shelters)
# - https://datasets.omdena.com/dataset/homelessness-in-the-united-states-(2007-2022) - best one so far (mainly going to use this one) for now just use the top major cities or states to use as data and put the data into an array manually
# - https://www.kaggle.com/datasets/mathurinache/natural-disasters-data-explorer - Dataset specifically highlighting natural disasters (Dataset highlights rates of homelessness)
# - https://datasetsearch.research.google.com/search?query=homelessness&docid=L2cvMTF3MzU0aG5mXw%3D%3D - This data includes people staying in emergency shelters and other programs serving those experiencing homelessness, as well as a head count of those identified as homeless in non-shelter locations on the night of the survey.

# %% [markdown]
# # Opening Paragraph / The Why

# %% [markdown]
# Homelessness in the United States is a multifaceted issue that permeates various different social and economic structures. Not only is it an ancient human tragedy where despair within society is highlighted, it is something that can be limited if certain factors are met. This project aims to demonstrate the scale of the issue by using datasets of various demographics, economic and real estate information, and other related data in order to create an accurate picture of this particular issue. That way, the people that seek to solve this problem are well informed and are equipped with the tools necessary in order to properly come up with ways to reduce the homeless population.

# %% [markdown]
# # Homelessness in the U.S.

# %% [markdown]
# **ENGR 1110 Group 14 Members:**
# - Alexander Arrington - Creative Director
# - Collin Ballitz - Developer
# - Lanham Boyd - Developer
# - Sam Lin - Product Owner
# - Cooper May - Scrum Master

# %% [markdown]
# **Global Issue:** The global issue that we are focusing is homelessness in the U.S. to understand why it is such an important problem not only in the U.S. but globally as well and how people typically put it under the radar and don't focus too much on it

# %% [markdown]
# **Data Collection:** The data collection that we did was searching through free and accessible datasets in order to find datasets that were recent enough in order to be used within the project

# %% [markdown]
# **Data Exploration and Visualization:** The process of looking through data in order to find good datasets was tedious since there are not that many datasets that are recent enough about homelessness to choose from so it took a while. It also took some time planning in order to think of the best method in order to build the visualization of the data which ended up using a combination of graphs such as bar or lines to visualize the data

# %% [markdown]
# **Message/Story:** Make the public more aware of homelessness and have everyone find a solution to the homeless population (more will be added)

# %% [markdown]
# **Possible Solutions:** Quick and temporary housing such as cargo houses to give them a place to stay. Also consider looking into the transportable small hosues that companies are now selling. (more will be added)

# %%
# 1 - Multidimensional Array that outputs stats of a state based off user input
# Cooper May
# extra note, maybe fix format of array to make it wider lol

import numpy as np
import pandas as pd


data = np.array([
    ["Alabama", 2570, 4887681],
    ["Alaska", 1434, 735139],
    ["Arizona", 7259, 7158024],
    ["Arkansas", 2280, 3009733],
    ["California", 109008, 39461588],
    ["Colorado", 7607, 5691287],
    ["Connecticut", 2280, 3571520],
    ["Delaware", 708, 965479],
    ["Florida", 21443, 21244317],
    ["Georgia", 6943, 10511131],
    ["Hawaii", 4131, 1420593],
    ["Idaho", 1297, 1750536],
    ["Illinois", 6752, 12723071],
    ["Indiana", 3776, 6695497],
    ["Iowa", 1711, 3148618],
    ["Kansas", 1443, 2911359],
    ["Kentucky", 2735, 4461153],
    ["Louisiana", 2540, 4659690],
    ["Maine", 1450, 1339057],
    ["Maryland", 4914, 6035802],
    ["Massachusetts", 6811, 6882635],
    ["Michigan", 5209, 9984072],
    ["Minnesota", 3993, 5606249],
    ["Mississippi", 1024, 2981020],
    ["Missouri", 3776, 6121623],
    ["Montana", 983, 1060665],
    ["Nebraska", 1745, 1925614],
    ["Nevada", 7058, 3027341],
    ["New Hampshire", 835, 1353465],
    ["New Jersey", 6048, 8886025],
    ["New Mexico", 1949, 2092741],
    ["New York", 39827, 19530351],
    ["North Carolina", 6451, 10381615],
    ["North Dakota", 467, 758080],
    ["Ohio", 6929, 11676341],
    ["Oklahoma", 2823, 3940235],
    ["Oregon", 11139, 4181886],
    ["Pennsylvania", 8163, 12800922],
    ["Rhode Island", 747, 1058287],
    ["South Carolina", 3082, 5084156],
    ["South Dakota", 836, 878698],
    ["Tennessee", 6139, 6771631],
    ["Texas", 19199, 28628666],
    ["Utah", 1904, 3153550],
    ["Vermont", 780, 624358],
    ["Virginia", 3928, 8501286],
    ["Washington", 16424, 7523869],
    ["West Virginia", 1021, 1804291],
    ["Wisconsin", 2740, 5807406],
    ["Wyoming", 434, 577601]
])
df = pd.DataFrame(data, columns=["State", "Homeless Individuals", "Total Population"])
df["Homeless Individuals"] = pd.to_numeric(df["Homeless Individuals"])
df["Total Population"] = pd.to_numeric(df["Total Population"])

# Calculate the percent of homeless individuals for each state
df["Homelessness Percent"] = (df["Homeless Individuals"] / df["Total Population"]) * 100

# Sort DataFrame by the homelessness percentage in descending order and reset the index
df = df.sort_values(by="Homelessness Percent", ascending=True).reset_index(drop=True)

# Prompt user for a state
state_name = input("Enter a US state: ")
filtered_df = df[df['State'].str.lower() == state_name.lower()]

if len(filtered_df) == 0:
    print(f"Sorry, {state_name} is not in the data.")
else:
    homelessness_percent = filtered_df.iloc[0]['Homelessness Percent']
    homelessness_individuals = filtered_df.iloc[0]['Homeless Individuals']
    total_population = filtered_df.iloc[0]['Total Population']
    rank = filtered_df.index[0] + 1  # Get the rank based on the sorted DataFrame index
    print(f"{state_name} has {homelessness_individuals:,} homeless people and a population of {total_population:,}.")
    print(f"In {state_name}, {homelessness_percent:.2f}% of the population is homeless.")
    print(f"{state_name} ranks {rank} in terms of homelessness percent among all states.")
# Out:
# Enter a US state: Alabama
# Alabama has 2,570 homeless people and a population of 4,887,681.
# In Alabama, 0.05% of the population is homeless.
# Alabama ranks 6 in terms of homelessness percent among all states.

# %%
# 2 - Graph that shows homeless individuals for each state
# Cooper May
import matplotlib.pyplot as plt

data = [
    ["Alabama", 2570, 4887681],["Alaska", 1434, 735139],["Arizona", 7259, 7158024],["Arkansas", 2280, 3009733],
    ["California", 109008, 39461588],["Colorado", 7607, 5691287],["Connecticut", 2280, 3571520],
    ["Delaware", 708, 965479],["Florida", 21443, 21244317],
    ["Georgia", 6943, 10511131],["Hawaii", 4131, 1420593],["Idaho", 1297, 1750536],["Illinois", 6752, 12723071],
    ["Indiana", 3776, 6695497],["Iowa", 1711, 3148618],["Kansas", 1443, 2911359],["Kentucky", 2735, 4461153],
    ["Louisiana", 2540, 4659690],["Maine", 1450, 1339057],["Maryland", 4914, 6035802],["Massachusetts", 6811, 6882635],
    ["Michigan", 5209, 9984072],["Minnesota", 3993, 5606249],["Mississippi", 1024, 2981020],["Missouri", 3776, 6121623],
    ["Montana", 983, 1060665],["Nebraska", 1745, 1925614],["Nevada", 7058, 3027341],["New Hampshire", 835, 1353465],
    ["New Jersey", 6048, 8886025],["New Mexico", 1949, 2092741],["New York", 39827, 19530351],["North Carolina", 6451, 10381615],
    ["North Dakota", 467, 758080],["Ohio", 6929, 11676341],["Oklahoma", 2823, 3940235],["Oregon", 11139, 4181886],
    ["Pennsylvania", 8163, 12800922],["Rhode Island", 747, 1058287],["South Carolina", 3082, 5084156],["South Dakota", 836, 878698],
    ["Tennessee", 6139, 6771631],["Texas", 19199, 28628666],["Utah", 1904, 3153550],["Vermont", 780, 624358],["Virginia", 3928, 8501286],
    ["Washington", 16424, 7523869],["West Virginia", 1021, 1804291],["Wisconsin", 2740, 5807406],["Wyoming", 434, 577601]
]
sorted_data = sorted(data, key=lambda x: x[1], reverse=True)
states = [item[0] for item in sorted_data]
homeless_individuals = [item[1] for item in sorted_data]


plt.bar(states, homeless_individuals,0.7, color='red')
plt.xticks(rotation=90, fontsize=6)
plt.subplots_adjust(bottom=0.25)
plt.xlabel('State')
plt.ylabel('Homeless Individuals')
plt.title('Homeless Individuals by US State')

plt.show()

# %%
# 3 - Graph that shows population of each U.S. State
# Cooper May
import matplotlib.pyplot as plt

data = [
    ["Alabama", 2570, 4887681],["Alaska", 1434, 735139],["Arizona", 7259, 7158024],["Arkansas", 2280, 3009733],
    ["California", 109008, 39461588],["Colorado", 7607, 5691287],["Connecticut", 2280, 3571520],
    ["Delaware", 708, 965479],["Florida", 21443, 21244317],
    ["Georgia", 6943, 10511131],["Hawaii", 4131, 1420593],["Idaho", 1297, 1750536],["Illinois", 6752, 12723071],
    ["Indiana", 3776, 6695497],["Iowa", 1711, 3148618],["Kansas", 1443, 2911359],["Kentucky", 2735, 4461153],
    ["Louisiana", 2540, 4659690],["Maine", 1450, 1339057],["Maryland", 4914, 6035802],["Massachusetts", 6811, 6882635],
    ["Michigan", 5209, 9984072],["Minnesota", 3993, 5606249],["Mississippi", 1024, 2981020],["Missouri", 3776, 6121623],
    ["Montana", 983, 1060665],["Nebraska", 1745, 1925614],["Nevada", 7058, 3027341],["New Hampshire", 835, 1353465],
    ["New Jersey", 6048, 8886025],["New Mexico", 1949, 2092741],["New York", 39827, 19530351],["North Carolina", 6451, 10381615],
    ["North Dakota", 467, 758080],["Ohio", 6929, 11676341],["Oklahoma", 2823, 3940235],["Oregon", 11139, 4181886],
    ["Pennsylvania", 8163, 12800922],["Rhode Island", 747, 1058287],["South Carolina", 3082, 5084156],["South Dakota", 836, 878698],
    ["Tennessee", 6139, 6771631],["Texas", 19199, 28628666],["Utah", 1904, 3153550],["Vermont", 780, 624358],["Virginia", 3928, 8501286],
    ["Washington", 16424, 7523869],["West Virginia", 1021, 1804291],["Wisconsin", 2740, 5807406],["Wyoming", 434, 577601]
]
sorted_data = sorted(data, key=lambda x: x[2], reverse=True)
states = [item[0] for item in sorted_data]
population = [item[2] for item in sorted_data]


plt.bar(states, population,0.7, color='brown')
plt.xticks(rotation=90, fontsize=6)
plt.subplots_adjust(bottom=0.25)
plt.xlabel('State')
plt.ylabel('Population')
plt.title('Population by US State')

plt.show()

# %%
# 4 - Graph That Shows Homelessness Percent for Each State
# Cooper May

import matplotlib.pyplot as plt

data = [
    ["Alabama", 2570, 4887681],["Alaska", 1434, 735139],["Arizona", 7259, 7158024],["Arkansas", 2280, 3009733],
    ["California", 109008, 39461588],["Colorado", 7607, 5691287],["Connecticut", 2280, 3571520],
    ["Delaware", 708, 965479],["Florida", 21443, 21244317],
    ["Georgia", 6943, 10511131],["Hawaii", 4131, 1420593],["Idaho", 1297, 1750536],["Illinois", 6752, 12723071],
    ["Indiana", 3776, 6695497],["Iowa", 1711, 3148618],["Kansas", 1443, 2911359],["Kentucky", 2735, 4461153],
    ["Louisiana", 2540, 4659690],["Maine", 1450, 1339057],["Maryland", 4914, 6035802],["Massachusetts", 6811, 6882635],
    ["Michigan", 5209, 9984072],["Minnesota", 3993, 5606249],["Mississippi", 1024, 2981020],["Missouri", 3776, 6121623],
    ["Montana", 983, 1060665],["Nebraska", 1745, 1925614],["Nevada", 7058, 3027341],["New Hampshire", 835, 1353465],
    ["New Jersey", 6048, 8886025],["New Mexico", 1949, 2092741],["New York", 39827, 19530351],["North Carolina", 6451, 10381615],
    ["North Dakota", 467, 758080],["Ohio", 6929, 11676341],["Oklahoma", 2823, 3940235],["Oregon", 11139, 4181886],
    ["Pennsylvania", 8163, 12800922],["Rhode Island", 747, 1058287],["South Carolina", 3082, 5084156],["South Dakota", 836, 878698],
    ["Tennessee", 6139, 6771631],["Texas", 19199, 28628666],["Utah", 1904, 3153550],["Vermont", 780, 624358],["Virginia", 3928, 8501286],
    ["Washington", 16424, 7523869],["West Virginia", 1021, 1804291],["Wisconsin", 2740, 5807406],["Wyoming", 434, 577601]
]
sorted_data = sorted(data, key=lambda x: (x[1] / x[2]) * 100, reverse=True)
states = [item[0] for item in sorted_data]
percentage = [(item[1] / item[2] * 100) for item in sorted_data]


plt.bar(states, percentage,0.7, color='black')
plt.xticks(rotation=90, fontsize=6)
plt.subplots_adjust(bottom=0.25)
plt.xlabel('State')
plt.ylabel('Homeless Percent')
plt.title('Homeless Percent by US State')

plt.show()

# i understand this isnt very good but its a start

# %%
# 5 - Multidimensional array that allows user to input a year and returns data for that year
# Sam Lin

import numpy as np
import pandas as pd

# %%
# 6 - Table of U.S. Homelessness Population Over the Years
# Sam Lin
# format better

import pandas as pd

usData = pd.read_csv('us-homelessness/us_data_csv.csv')
print(usData)

# nts graph that shows the increase in percentage? given two years as input
# graph that shows over the years
# Out:
#     year  sheltered  unsheltered   total
# 0   2007     391401       255857  647258
# 1   2008     386361       253423  639784
# 2   2009     403308       226919  630227
# 3   2010     403543       233534  637077
# 4   2011     392316       231472  623788
# 5   2012     390155       231398  621553
# 6   2013     394698       195666  590364
# 7   2014     401051       175399  576450
# 8   2015     391440       173268  564708
# 9   2016     373571       176357  549928
# 10  2017     360867       190129  550996
# 11  2018     358363       194467  552830

# %%
# 6.5 will reorder blocks
# Sam Lin

import pandas as pd
import matplotlib.pyplot as plt

usData = pd.read_csv('us-homelessness/us_data_csv.csv')

plt.plot(usData["year"], usData["total"], marker = 'o')
plt.xlabel("Year")
plt.ylabel("Homeless Population")
plt.title("Homeless Population Over Time in U.S.")
plt.grid(True)
# check to see to show more ticks in axis
plt.show()

# %% [markdown]
# ones below

# %%
# 7 maybe insert a table that displays all possible homeless shelters in a table and allows the user to look at it? - maybe later
# Collin Bailitz

# %%
# 8 insert graph for a certain state based off user input (maybe more specification, and maybe allows user to reinput if needed) using matplotlib - maybe later

# %%
# 9 maybe insert a gif that shows the growth of homelessness over time - maybe later
#Lanham Boyd

# %%
# 10 maybe find a dataset that shows homeless solutions and how it can improve it over time - maybe later
#Lanham Boyd

# %%
# 11 maybe find a dataset that shows how homelessness increases after natural disasters such as hurricanes
# Collin Bailitz

# %%
# 12 maybbe find a dataset involving natural disasters and how it affected homeless pop and display it as a graph
# Collin Bailitz

# %%
# 13 maybe do a graph showing solutions of homelessness

# %% [markdown]
# **Attribution/Copyright:**
# - https://www.kaggle.com/datasets/barri12/homelessness
# - https://www.kaggle.com/datasets/beelaboo/us-homelessness

# %% [markdown]
# **Trello Board:** https://trello.com/b/Fp7nSHTC/engr-1110-group-project
